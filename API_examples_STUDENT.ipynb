# %% [markdown]
# # APIs

# %% [markdown]
# >- An API, or Application Programming Interface, is a server that you can use to retrieve and send data to using code. APIs are most commonly used to retrieve data, and that will be the focus of this beginner tutorial.
#
# >- When we want to receive data from an API, we need to make a request.
# >- Requests are used all over the web.
# >>- For instance, when you visited a blog post, your web browser made a request to the Dataquest web server, which responded with the content of a web page.

# %% [markdown]
# ### Requests Libary
# >- In order to work with APIs in Python, we need tools that will make those requests.
# >- In Python, the most common library for making requests and working with APIs is the requests library.

# %% [markdown]
# ### API Status Codes
# >- 200: Everything went okay, and the result has been returned (if any).
# >- 301: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or >- an endpoint name is changed.
# >- 400: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other >- things.
# >- 401: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t >- send the right credentials to access an API.
# >- 403: The resource you’re trying to access is forbidden: you don’t have the right permissions to see it.
# >- 404: The resource you tried to access wasn’t found on the server.
# >- 503: The server is not ready to handle the request.

# %% [markdown]
# ### SOAP vs REST APIs
# >- SOAP (Simple Object Access Protocol) is typically associated with the enterprise world, has a stricter contract-based usage, and is mostly designed around actions.
# >- REST (Representational State Transfer) is typically used for public APIs and is ideal for fetching data from the web. It’s much lighter and closer to the HTTP specification than SOAP.

# %% [markdown]
# ### Installing new packages to Anaconda
# https://docs.anaconda.com/anaconda/user-guide/tasks/install-packages/

# %% [markdown]
# ### Formula 1 API
# https://ergast.com/mrd/

# %% [markdown]
# ##### Import packages

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ##### Make `get` request

# %%
response = requests.get('http://ergast.com/api/f1/year')

# %% [markdown]
# ##### Return status code to check on request

# %%
response.status_code
# Out:
# 400

# %% [markdown]
# ##### Try again

# %%
response = requests.get('http://ergast.com/api/f1/2020.json')

# %% [markdown]
# ##### Deal with the api response

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ##### Drill into the data

# %%
data = response.json()

data.get('MRData').get('RaceTable').get('Races')
# Out:
# [{'season': '2020',
#   'round': '1',
#   'url': 'https://en.wikipedia.org/wiki/2020_Austrian_Grand_Prix',
#   'raceName': 'Austrian Grand Prix',
#   'Circuit': {'circuitId': 'red_bull_ring',
#    'url': 'http://en.wikipedia.org/wiki/Red_Bull_Ring',
#    'circuitName': 'Red Bull Ring',
#    'Location': {'lat': '47.2197',
#     'long': '14.7647',
#     'locality': 'Spielberg',
#     'country': 'Austria'}},
#   'date': '2020-07-05',
#   'time': '13:10:00Z'},
#  {'season': '2020',
#   'round': '2',
#   'url': 'https://en.wikipedia.org/wiki/2020_Styrian_Grand_Prix',
#   'raceName': 'Styrian Grand Prix',
#   'Circuit': {'circuitId': 'red_bull_ring',
#    'url': 'http://en.wikipedia.org/wiki/Red_Bull_Ring',
#    'circuitName': 'Red Bull Ring',
#    'Location': {'lat': '47.2197',
#     'long': '14.7647',
#     'locality': 'Spielberg',
#     'country': 'Austria'}},
#   'date': '2020-07-12',
#   'time': '13:10:00Z'},
#  {'season': '2020',
#   'round': '3',
#   'url': 'https://en.wikipedia.org/wiki/2020_Hungarian_Grand_Prix',
#   'raceName': 'Hungarian Grand Prix',
#   'Circuit': {'circuitId': 'hungaroring',
#    'url': 'http://en.wikipedia.org/wiki/Hungaroring',
#    'circuitName': 'Hungaroring',
#    'Location': {'lat': '47.5789',
#     'long': '19.2486',
#     'locality': 'Budapest',
#     'country': 'Hungary'}},
#   'date': '2020-07-19',
#   'time': '13:10:00Z'},
#  {'season': '2020',
#   'round': '4',
#   'url': 'https://en.wikipedia.org/wiki/2020_British_Grand_Prix',
#   'raceName': 'British Grand Prix',
#   'Circuit': {'circuitId': 'silverstone',
#    'url': 'http://en.wikipedia.org/wiki/Silverstone_Circuit',
#    'circuitName': 'Silverstone Circuit',
#    'Location': {'lat': '52.0786',
#     'long': '-1.01694',
#     'locality': 'Silverstone',
#     'country': 'UK'}},
#   'date': '2020-08-02',
#   'time': '13:10:00Z'},
#  {'season': '2020',
#   'round': '5',
#   'url': 'https://en.wikipedia.org/wiki/70th_Anniversary_Grand_Prix',
#   'raceName': '70th Anniversary Grand Prix',
#   'Circuit': {'circuitId': 'silverstone',
#    'url': 'http://en.wikipedia.org/wiki/Silverstone_Circuit',
#    'circuitName': 'Silverstone Circuit',
#    'Location': {'lat': '52.0786',
#     'long': '-1.01694',
#     'locality': 'Silverstone',
#     'country': 'UK'}},
#   'date': '2020-08-09',
#   'time': '13:10:00Z'},
#  {'season': '2020',
#   'round': '6',
#   'url': 'https://en.wikipedia.org/wiki/2020_Spanish_Grand_Prix',
#   'raceName': 'Spanish Grand Prix',
#   'Circuit': {'circuitId': 'catalunya',
#    'url': 'http://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya',
#    'circuitName': 'Circuit de Barcelona-Catalunya',
#    'Location': {'lat': '41.57',
#     'long': '2.26111',
#     'locality': 'Montmeló',
#     'country': 'Spain'}},
#   'date': '2020-08-16',
#   'time': '13:10:00Z'},
#  {'season': '2020',
#   'round': '7',
#   'url': 'https://en.wikipedia.org/wiki/2020_Belgian_Grand_Prix',
#   'raceName': 'Belgian Grand Prix',
#   'Circuit': {'circuitId': 'spa',
#    'url': 'http://en.wikipedia.org/wiki/Circuit_de_Spa-Francorchamps',
#    'circuitName': 'Circuit de Spa-Francorchamps',
#    'Location': {'lat': '50.4372',
#     'long': '5.97139',
#     'locality': 'Spa',
#     'country': 'Belgium'}},
#   'date': '2020-08-30',
#   'time': '13:10:00Z'},
#  {'season': '2020',
#   'round': '8',
#   'url': 'https://en.wikipedia.org/wiki/2020_Italian_Grand_Prix',
#   'raceName': 'Italian Grand Prix',
#   'Circuit': {'circuitId': 'monza',
#    'url': 'http://en.wikipedia.org/wiki/Autodromo_Nazionale_Monza',
#    'circuitName': 'Autodromo Nazionale di Monza',
#    'Location': {'lat': '45.6156',
#     'long': '9.28111',
#     'locality': 'Monza',
#     'country': 'Italy'}},
#   'date': '2020-09-06',
#   'time': '13:10:00Z'},
#  {'season': '2020',
#   'round': '9',
#   'url': 'https://en.wikipedia.org/wiki/2020_Tuscan_Grand_Prix',
#   'raceName': 'Tuscan Grand Prix',
#   'Circuit': {'circuitId': 'mugello',
#    'url': 'http://en.wikipedia.org/wiki/Mugello_Circuit',
#    'circuitName': 'Autodromo Internazionale del Mugello',
#    'Location': {'lat': '43.9975',
#     'long': '11.3719',
#     'locality': 'Mugello',
#     'country': 'Italy'}},
#   'date': '2020-09-13',
#   'time': '13:10:00Z'},
#  {'season': '2020',
#   'round': '10',
#   'url': 'https://en.wikipedia.org/wiki/2020_Russian_Grand_Prix',
#   'raceName': 'Russian Grand Prix',
#   'Circuit': {'circuitId': 'sochi',
#    'url': 'http://en.wikipedia.org/wiki/Sochi_Autodrom',
#    'circuitName': 'Sochi Autodrom',
#    'Location': {'lat': '43.4057',
#     'long': '39.9578',
#     'locality': 'Sochi',
#     'country': 'Russia'}},
#   'date': '2020-09-27',
#   'time': '11:10:00Z'},
#  {'season': '2020',
#   'round': '11',
#   'url': 'https://en.wikipedia.org/wiki/2020_Eifel_Grand_Prix',
#   'raceName': 'Eifel Grand Prix',
#   'Circuit': {'circuitId': 'nurburgring',
#    'url': 'http://en.wikipedia.org/wiki/N%C3%BCrburgring',
#    'circuitName': 'Nürburgring',
#    'Location': {'lat': '50.3356',
#     'long': '6.9475',
#     'locality': 'Nürburg',
#     'country': 'Germany'}},
#   'date': '2020-10-11',
#   'time': '13:10:00Z'},
#  {'season': '2020',
#   'round': '12',
#   'url': 'https://en.wikipedia.org/wiki/2020_Portuguese_Grand_Prix',
#   'raceName': 'Portuguese Grand Prix',
#   'Circuit': {'circuitId': 'portimao',
#    'url': 'http://en.wikipedia.org/wiki/Algarve_International_Circuit',
#    'circuitName': 'Autódromo Internacional do Algarve',
#    'Location': {'lat': '37.227',
#     'long': '-8.6267',
#     'locality': 'Portimão',
#     'country': 'Portugal'}},
#   'date': '2020-10-25',
#   'time': '12:10:00Z'},
#  {'season': '2020',
#   'round': '13',
#   'url': 'https://en.wikipedia.org/wiki/2020_Emilia_Romagna_Grand_Prix',
#   'raceName': 'Emilia Romagna Grand Prix',
#   'Circuit': {'circuitId': 'imola',
#    'url': 'http://en.wikipedia.org/wiki/Autodromo_Enzo_e_Dino_Ferrari',
#    'circuitName': 'Autodromo Enzo e Dino Ferrari',
#    'Location': {'lat': '44.3439',
#     'long': '11.7167',
#     'locality': 'Imola',
#     'country': 'Italy'}},
#   'date': '2020-11-01',
#   'time': '12:10:00Z'},
#  {'season': '2020',
#   'round': '14',
#   'url': 'https://en.wikipedia.org/wiki/2020_Turkish_Grand_Prix',
#   'raceName': 'Turkish Grand Prix',
#   'Circuit': {'circuitId': 'istanbul',
#    'url': 'http://en.wikipedia.org/wiki/Istanbul_Park',
#    'circuitName': 'Istanbul Park',
#    'Location': {'lat': '40.9517',
#     'long': '29.405',
#     'locality': 'Istanbul',
#     'country': 'Turkey'}},
#   'date': '2020-11-15',
#   'time': '10:10:00Z'},
#  {'season': '2020',
#   'round': '15',
#   'url': 'https://en.wikipedia.org/wiki/2020_Bahrain_Grand_Prix',
#   'raceName': 'Bahrain Grand Prix',
#   'Circuit': {'circuitId': 'bahrain',
#    'url': 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#    'circuitName': 'Bahrain International Circuit',
#    'Location': {'lat': '26.0325',
#     'long': '50.5106',
#     'locality': 'Sakhir',
#     'country': 'Bahrain'}},
#   'date': '2020-11-29',
#   'time': '14:10:00Z'},
#  {'season': '2020',
#   'round': '16',
#   'url': 'https://en.wikipedia.org/wiki/2020_Sakhir_Grand_Prix',
#   'raceName': 'Sakhir Grand Prix',
#   'Circuit': {'circuitId': 'bahrain',
#    'url': 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#    'circuitName': 'Bahrain International Circuit',
#    'Location': {'lat': '26.0325',
#     'long': '50.5106',
#     'locality': 'Sakhir',
#     'country': 'Bahrain'}},
#   'date': '2020-12-06',
#   'time': '17:10:00Z'},
#  {'season': '2020',
#   'round': '17',
#   'url': 'https://en.wikipedia.org/wiki/2020_Abu_Dhabi_Grand_Prix',
#   'raceName': 'Abu Dhabi Grand Prix',
#   'Circuit': {'circuitId': 'yas_marina',
#    'url': 'http://en.wikipedia.org/wiki/Yas_Marina_Circuit',
#    'circuitName': 'Yas Marina Circuit',
#    'Location': {'lat': '24.4672',
#     'long': '54.6031',
#     'locality': 'Abu Dhabi',
#     'country': 'UAE'}},
#   'date': '2020-12-13',
#   'time': '13:10:00Z'}]

# %% [markdown]
# ##### Convert to pandas table

# %%
pd.DataFrame(data.get('MRData').get('RaceTable').get('Races'))
# Out:
#    season round                                                url  \
# 0    2020     1  https://en.wikipedia.org/wiki/2020_Austrian_Gr...
# 1    2020     2  https://en.wikipedia.org/wiki/2020_Styrian_Gra...
# 2    2020     3  https://en.wikipedia.org/wiki/2020_Hungarian_G...
# 3    2020     4  https://en.wikipedia.org/wiki/2020_British_Gra...
# 4    2020     5  https://en.wikipedia.org/wiki/70th_Anniversary...
# 5    2020     6  https://en.wikipedia.org/wiki/2020_Spanish_Gra...
# 6    2020     7  https://en.wikipedia.org/wiki/2020_Belgian_Gra...
# 7    2020     8  https://en.wikipedia.org/wiki/2020_Italian_Gra...
# 8    2020     9  https://en.wikipedia.org/wiki/2020_Tuscan_Gran...
# 9    2020    10  https://en.wikipedia.org/wiki/2020_Russian_Gra...
# 10   2020    11  https://en.wikipedia.org/wiki/2020_Eifel_Grand...
# 11   2020    12  https://en.wikipedia.org/wiki/2020_Portuguese_...
# 12   2020    13  https://en.wikipedia.org/wiki/2020_Emilia_Roma...
# 13   2020    14  https://en.wikipedia.org/wiki/2020_Turkish_Gra...
# 14   2020    15  https://en.wikipedia.org/wiki/2020_Bahrain_Gra...
# 15   2020    16  https://en.wikipedia.org/wiki/2020_Sakhir_Gran...
# 16   2020    17  https://en.wikipedia.org/wiki/2020_Abu_Dhabi_G...
#
#                        raceName  \
# 0           Austrian Grand Prix
# 1            Styrian Grand Prix
# 2          Hungarian Grand Prix
# 3            British Grand Prix
# 4   70th Anniversary Grand Prix
# 5            Spanish Grand Prix
# 6            Belgian Grand Prix
# 7            Italian Grand Prix
# 8             Tuscan Grand Prix
# 9            Russian Grand Prix
# 10             Eifel Grand Prix
# 11        Portuguese Grand Prix
# 12    Emilia Romagna Grand Prix
# 13           Turkish Grand Prix
# 14           Bahrain Grand Prix
# 15            Sakhir Grand Prix
# 16         Abu Dhabi Grand Prix
#
#                                               Circuit        date       time
# 0   {'circuitId': 'red_bull_ring', 'url': 'http://...  2020-07-05  13:10:00Z
# 1   {'circuitId': 'red_bull_ring', 'url': 'http://...  2020-07-12  13:10:00Z
# 2   {'circuitId': 'hungaroring', 'url': 'http://en...  2020-07-19  13:10:00Z
# 3   {'circuitId': 'silverstone', 'url': 'http://en...  2020-08-02  13:10:00Z
# 4   {'circuitId': 'silverstone', 'url': 'http://en...  2020-08-09  13:10:00Z
# 5   {'circuitId': 'catalunya', 'url': 'http://en.w...  2020-08-16  13:10:00Z
# 6   {'circuitId': 'spa', 'url': 'http://en.wikiped...  2020-08-30  13:10:00Z
# 7   {'circuitId': 'monza', 'url': 'http://en.wikip...  2020-09-06  13:10:00Z
# 8   {'circuitId': 'mugello', 'url': 'http://en.wik...  2020-09-13  13:10:00Z
# 9   {'circuitId': 'sochi', 'url': 'http://en.wikip...  2020-09-27  11:10:00Z
# 10  {'circuitId': 'nurburgring', 'url': 'http://en...  2020-10-11  13:10:00Z
# 11  {'circuitId': 'portimao', 'url': 'http://en.wi...  2020-10-25  12:10:00Z
# 12  {'circuitId': 'imola', 'url': 'http://en.wikip...  2020-11-01  12:10:00Z
# 13  {'circuitId': 'istanbul', 'url': 'http://en.wi...  2020-11-15  10:10:00Z
# 14  {'circuitId': 'bahrain', 'url': 'http://en.wik...  2020-11-29  14:10:00Z
# 15  {'circuitId': 'bahrain', 'url': 'http://en.wik...  2020-12-06  17:10:00Z
# 16  {'circuitId': 'yas_marina', 'url': 'http://en....  2020-12-13  13:10:00Z

# %% [markdown]
# ##### Github Example

# %% [markdown]
# ##### `get` Request

# %%
response = requests.get('https://api.github.com')
response.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}

# %%
response_1 = requests.get(
                'https://api.github.com/search/repositories',
                    params = {'q':'requests+language:python'}
                )
response_1
# Out:
# <Response [200]>

# %%
data = response_1.json()
github_dat = pd.DataFrame(data['items'])
github_dat
# Out:
#            id                           node_id                        name  \
# 0     4290214      MDEwOlJlcG9zaXRvcnk0MjkwMjE0                   grequests
# 1     6825724      MDEwOlJlcG9zaXRvcnk2ODI1NzI0           requests-oauthlib
# 2   172416496  MDEwOlJlcG9zaXRvcnkxNzI0MTY0OTY=                DecryptLogin
# 3    51690353  MDEwOlJlcG9zaXRvcnk1MTY5MDM1Mw==                 python-zeep
# 4      760165      MDEwOlJlcG9zaXRvcnk3NjAxNjU=                    buildbot
# 5    62032720  MDEwOlJlcG9zaXRvcnk2MjAzMjcyMA==                 weibospider
# 6    14437755  MDEwOlJlcG9zaXRvcnkxNDQzNzc1NQ==                   responses
# 7     2246709      MDEwOlJlcG9zaXRvcnkyMjQ2NzA5     robotframework-requests
# 8     3073296      MDEwOlJlcG9zaXRvcnkzMDczMjk2                   ultisnips
# 9    18470996  MDEwOlJlcG9zaXRvcnkxODQ3MDk5Ng==                      uncurl
# 10   40554408  MDEwOlJlcG9zaXRvcnk0MDU1NDQwOA==                     dnsteal
# 11    8930430      MDEwOlJlcG9zaXRvcnk4OTMwNDMw            requests-futures
# 12    6705902      MDEwOlJlcG9zaXRvcnk2NzA1OTAy               requests-ntlm
# 13    1778471      MDEwOlJlcG9zaXRvcnkxNzc4NDcx                     httpbin
# 14  176784301  MDEwOlJlcG9zaXRvcnkxNzY3ODQzMDE=              requests-async
# 15    8891992      MDEwOlJlcG9zaXRvcnk4ODkxOTky                     httmock
# 16    1303056      MDEwOlJlcG9zaXRvcnkxMzAzMDU2                   HTTPretty
# 17   85674218  MDEwOlJlcG9zaXRvcnk4NTY3NDIxOA==                SSRF-Testing
# 18   80945517  MDEwOlJlcG9zaXRvcnk4MDk0NTUxNw==                        asks
# 19   45270722  MDEwOlJlcG9zaXRvcnk0NTI3MDcyMg==     HTTP_Request_Randomizer
# 20   98755682  MDEwOlJlcG9zaXRvcnk5ODc1NTY4Mg==                 GithubLogin
# 21  143563911  MDEwOlJlcG9zaXRvcnkxNDM1NjM5MTE=              proxy_requests
# 22   10754954  MDEwOlJlcG9zaXRvcnkxMDc1NDk1NA==                cachecontrol
# 23   36250659  MDEwOlJlcG9zaXRvcnkzNjI1MDY1OQ==                drf-tracking
# 24   61938302  MDEwOlJlcG9zaXRvcnk2MTkzODMwMg==              imooc-requests
# 25    2406348      MDEwOlJlcG9zaXRvcnkyNDA2MzQ4                       webob
# 26   28104322  MDEwOlJlcG9zaXRvcnkyODEwNDMyMg==               requests-mock
# 27    6710117      MDEwOlJlcG9zaXRvcnk2NzEwMTE3           requests-kerberos
# 28   95916519  MDEwOlJlcG9zaXRvcnk5NTkxNjUxOQ==                  requestium
# 29    2201158      MDEwOlJlcG9zaXRvcnkyMjAxMTU4  robotframework-httplibrary
#
#                                full_name  private  \
# 0                  spyoungtech/grequests    False
# 1             requests/requests-oauthlib    False
# 2            CharlesPikachu/DecryptLogin    False
# 3              mvantellingen/python-zeep    False
# 4                      buildbot/buildbot    False
# 5                 SpiderClub/weibospider    False
# 6                    getsentry/responses    False
# 7   MarketSquare/robotframework-requests    False
# 8                       SirVer/ultisnips    False
# 9                          spulec/uncurl    False
# 10                           m57/dnsteal    False
# 11                 ross/requests-futures    False
# 12                requests/requests-ntlm    False
# 13                   postmanlabs/httpbin    False
# 14                 encode/requests-async    False
# 15                        patrys/httmock    False
# 16               gabrielfalcao/HTTPretty    False
# 17                cujanovic/SSRF-Testing    False
# 18                        theelous3/asks    False
# 19        pgaref/HTTP_Request_Randomizer    False
# 20          Python3WebSpider/GithubLogin    False
# 21               rootVIII/proxy_requests    False
# 22                  ionrock/cachecontrol    False
# 23                    aschn/drf-tracking    False
# 24                jian-en/imooc-requests    False
# 25                          Pylons/webob    False
# 26             jamielennox/requests-mock    False
# 27            requests/requests-kerberos    False
# 28                   tryolabs/requestium    False
# 29    peritus/robotframework-httplibrary    False
#
#                                                 owner  \
# 0   {'login': 'spyoungtech', 'id': 15212758, 'node...
# 1   {'login': 'requests', 'id': 2805331, 'node_id'...
# 2   {'login': 'CharlesPikachu', 'id': 36195560, 'n...
# 3   {'login': 'mvantellingen', 'id': 245297, 'node...
# 4   {'login': 'buildbot', 'id': 324515, 'node_id':...
# 5   {'login': 'SpiderClub', 'id': 32793535, 'node_...
# 6   {'login': 'getsentry', 'id': 1396951, 'node_id...
# 7   {'login': 'MarketSquare', 'id': 57290362, 'nod...
# 8   {'login': 'SirVer', 'id': 140115, 'node_id': '...
# 9   {'login': 'spulec', 'id': 292606, 'node_id': '...
# 10  {'login': 'm57', 'id': 6309826, 'node_id': 'MD...
# 11  {'login': 'ross', 'id': 12789, 'node_id': 'MDQ...
# 12  {'login': 'requests', 'id': 2805331, 'node_id'...
# 13  {'login': 'postmanlabs', 'id': 10251060, 'node...
# 14  {'login': 'encode', 'id': 19159390, 'node_id':...
# 15  {'login': 'patrys', 'id': 81205, 'node_id': 'M...
# 16  {'login': 'gabrielfalcao', 'id': 54914, 'node_...
# 17  {'login': 'cujanovic', 'id': 7038277, 'node_id...
# 18  {'login': 'theelous3', 'id': 19316042, 'node_i...
# 19  {'login': 'pgaref', 'id': 2953485, 'node_id': ...
# 20  {'login': 'Python3WebSpider', 'id': 29157219, ...
# 21  {'login': 'rootVIII', 'id': 30498791, 'node_id...
# 22  {'login': 'ionrock', 'id': 509830, 'node_id': ...
# 23  {'login': 'aschn', 'id': 3664000, 'node_id': '...
# 24  {'login': 'jian-en', 'id': 11342080, 'node_id'...
# 25  {'login': 'Pylons', 'id': 452227, 'node_id': '...
# 26  {'login': 'jamielennox', 'id': 416057, 'node_i...
# 27  {'login': 'requests', 'id': 2805331, 'node_id'...
# 28  {'login': 'tryolabs', 'id': 591820, 'node_id':...
# 29  {'login': 'peritus', 'id': 11022, 'node_id': '...
#
#                                              html_url  \
# 0            https://github.com/spyoungtech/grequests
# 1       https://github.com/requests/requests-oauthlib
# 2      https://github.com/CharlesPikachu/DecryptLogin
# 3        https://github.com/mvantellingen/python-zeep
# 4                https://github.com/buildbot/buildbot
# 5           https://github.com/SpiderClub/weibospider
# 6              https://github.com/getsentry/responses
# 7   https://github.com/MarketSquare/robotframework...
# 8                 https://github.com/SirVer/ultisnips
# 9                    https://github.com/spulec/uncurl
# 10                     https://github.com/m57/dnsteal
# 11           https://github.com/ross/requests-futures
# 12          https://github.com/requests/requests-ntlm
# 13             https://github.com/postmanlabs/httpbin
# 14           https://github.com/encode/requests-async
# 15                  https://github.com/patrys/httmock
# 16         https://github.com/gabrielfalcao/HTTPretty
# 17          https://github.com/cujanovic/SSRF-Testing
# 18                  https://github.com/theelous3/asks
# 19  https://github.com/pgaref/HTTP_Request_Randomizer
# 20    https://github.com/Python3WebSpider/GithubLogin
# 21         https://github.com/rootVIII/proxy_requests
# 22            https://github.com/ionrock/cachecontrol
# 23              https://github.com/aschn/drf-tracking
# 24          https://github.com/jian-en/imooc-requests
# 25                    https://github.com/Pylons/webob
# 26       https://github.com/jamielennox/requests-mock
# 27      https://github.com/requests/requests-kerberos
# 28             https://github.com/tryolabs/requestium
# 29  https://github.com/peritus/robotframework-http...
#
#                                           description   fork  \
# 0                              Requests + Gevent = <3  False
# 1               OAuthlib support for Python-Requests!  False
# 2   APIs for loginning some websites by using requ...  False
# 3   A modern/fast python SOAP client based on lxml...  False
# 4   Python-based continuous integration testing fr...  False
# 5   :zap: A distributed crawler for weibo, buildin...  False
# 6   A utility for mocking out the Python Requests ...  False
# 7   Robot Framework keyword library wrapper for re...  False
# 8   UltiSnips - The ultimate snippet solution for ...  False
# 9   A library to convert curl requests to python-r...  False
# 10  DNS Exfiltration tool for stealthily sending f...  False
# 11  Asynchronous Python HTTP Requests for Humans u...  False
# 12          NTLM authentication support for Requests.  False
# 13  HTTP Request & Response Service, written in Py...  False
# 14          async-await support for `requests`. ✨ 🍰 ✨  False
# 15                     A mocking library for requests  False
# 16  Intercept HTTP requests at the Python socket l...  False
# 17  SSRF (Server Side Request Forgery) testing res...  False
# 18            Async requests-like httplib for python.  False
# 19                           Proxying Python Requests  False
# 20                         Login Github with Requests  False
# 21  a class that uses scraped proxies to make http...  False
# 22  The httplib2 caching algorithms packaged up fo...  False
# 23  Utils to track requests to Django Rest Framewo...  False
# 24              python requests course for pythonists  False
# 25                  WSGI request and response objects  False
# 26          Mocked responses for the requests library  False
# 27  An authentication handler for using Kerberos w...  False
# 28  Integration layer between Requests and Seleniu...  False
# 29         Robot Framework keywords for HTTP requests  False
#
#                                                   url  ...  \
# 0   https://api.github.com/repos/spyoungtech/grequ...  ...
# 1   https://api.github.com/repos/requests/requests...  ...
# 2   https://api.github.com/repos/CharlesPikachu/De...  ...
# 3   https://api.github.com/repos/mvantellingen/pyt...  ...
# 4      https://api.github.com/repos/buildbot/buildbot  ...
# 5   https://api.github.com/repos/SpiderClub/weibos...  ...
# 6    https://api.github.com/repos/getsentry/responses  ...
# 7   https://api.github.com/repos/MarketSquare/robo...  ...
# 8       https://api.github.com/repos/SirVer/ultisnips  ...
# 9          https://api.github.com/repos/spulec/uncurl  ...
# 10           https://api.github.com/repos/m57/dnsteal  ...
# 11  https://api.github.com/repos/ross/requests-fut...  ...
# 12  https://api.github.com/repos/requests/requests...  ...
# 13   https://api.github.com/repos/postmanlabs/httpbin  ...
# 14  https://api.github.com/repos/encode/requests-a...  ...
# 15        https://api.github.com/repos/patrys/httmock  ...
# 16  https://api.github.com/repos/gabrielfalcao/HTT...  ...
# 17  https://api.github.com/repos/cujanovic/SSRF-Te...  ...
# 18        https://api.github.com/repos/theelous3/asks  ...
# 19  https://api.github.com/repos/pgaref/HTTP_Reque...  ...
# 20  https://api.github.com/repos/Python3WebSpider/...  ...
# 21  https://api.github.com/repos/rootVIII/proxy_re...  ...
# 22  https://api.github.com/repos/ionrock/cachecontrol  ...
# 23    https://api.github.com/repos/aschn/drf-tracking  ...
# 24  https://api.github.com/repos/jian-en/imooc-req...  ...
# 25          https://api.github.com/repos/Pylons/webob  ...
# 26  https://api.github.com/repos/jamielennox/reque...  ...
# 27  https://api.github.com/repos/requests/requests...  ...
# 28   https://api.github.com/repos/tryolabs/requestium  ...
# 29  https://api.github.com/repos/peritus/robotfram...  ...
#
#                                               license allow_forking  \
# 0   {'key': 'bsd-2-clause', 'name': 'BSD 2-Clause ...          True
# 1   {'key': 'isc', 'name': 'ISC License', 'spdx_id...          True
# 2   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 3   {'key': 'other', 'name': 'Other', 'spdx_id': '...          True
# 4   {'key': 'gpl-2.0', 'name': 'GNU General Public...          True
# 5   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 6   {'key': 'apache-2.0', 'name': 'Apache License ...          True
# 7   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 8   {'key': 'gpl-3.0', 'name': 'GNU General Public...          True
# 9   {'key': 'apache-2.0', 'name': 'Apache License ...          True
# 10  {'key': 'gpl-2.0', 'name': 'GNU General Public...          True
# 11  {'key': 'other', 'name': 'Other', 'spdx_id': '...          True
# 12  {'key': 'isc', 'name': 'ISC License', 'spdx_id...          True
# 13  {'key': 'isc', 'name': 'ISC License', 'spdx_id...          True
# 14  {'key': 'other', 'name': 'Other', 'spdx_id': '...          True
# 15  {'key': 'other', 'name': 'Other', 'spdx_id': '...          True
# 16  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 17                                               None          True
# 18  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 19  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 20                                               None          True
# 21  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 22  {'key': 'other', 'name': 'Other', 'spdx_id': '...          True
# 23  {'key': 'isc', 'name': 'ISC License', 'spdx_id...          True
# 24                                               None          True
# 25                                               None          True
# 26  {'key': 'apache-2.0', 'name': 'Apache License ...          True
# 27  {'key': 'isc', 'name': 'ISC License', 'spdx_id...          True
# 28  {'key': 'bsd-3-clause', 'name': 'BSD 3-Clause ...          True
# 29                                               None          True
#
#    is_template                                             topics visibility  \
# 0        False                                                 []     public
# 1        False  [oauth-client, oauth2-client, python, python-r...     public
# 2        False  [12306, baidu, baiduyun, bilibili, crawler, ji...     public
# 3        False                  [python, soap, soap-client, wsdl]     public
# 4        False  [ci, ci-framework, continuous-integration, pyt...     public
# 5        False  [data-analysis, distributed-crawler, python3, ...     public
# 6        False                                                 []     public
# 7        False  [python, requests, robot-framework, robotframe...     public
# 8        False                 [plugin, snippets, ultisnips, vim]     public
# 9        False                                                 []     public
# 10       False                                                 []     public
# 11       False                                                 []     public
# 12       False                                                 []     public
# 13       False  [api, http, http-server, httpbin, json, python...     public
# 14       False                                                 []     public
# 15       False                     [http, mock, python, requests]     public
# 16       False  [decorators, fakeweb, http, httpretty, mock, m...     public
# 17       False  [pentest, pentest-tool, pentesting, server-sid...     public
# 18       False  [async, async-requests, concurrency, curio, ht...     public
# 19       False  [anonymity, http, proxies, proxy, python, requ...     public
# 20       False                                                 []     public
# 21       False  [http, http-get, http-getter, http-proxy, http...     public
# 22       False                                                 []     public
# 23       False                                                 []     public
# 24       False                                                 []     public
# 25       False                                                 []     public
# 26       False                                                 []     public
# 27       False  [kerberos-authentication, python, python-reque...     public
# 28       False  [interface, python, requests, selenium, web-au...     public
# 29       False                                                 []     public
#
#    forks open_issues watchers default_branch score
# 0    337           9     3902         master   1.0
# 1    388         113     1438         master   1.0
# 2    523          23     1842         master   1.0
# 3    522         375     1634         master   1.0
# 4   1558         631     4724         master   1.0
# 5   1272          17     4670         master   1.0
# 6    284          42     3388         master   1.0
# 7    255          28      372         master   1.0
# 8    641          82     6444         master   1.0
# 9     64          12      428         master   1.0
# 10   216           4     1242         master   1.0
# 11   149          20     1857         master   1.0
# 12    93          25      272         master   1.0
# 13  1533         156    10373         master   1.0
# 14    37           0      940         master   1.0
# 15    51          15      432         master   1.0
# 16   253          96     1922         master   1.0
# 17   406           0     1708         master   1.0
# 18    64          40      462         master   1.0
# 19    50          21      128         master   1.0
# 20    63           2       63         master   1.0
# 21    44           2      372         master   1.0
# 22   101          58      392         master   1.0
# 23    99          43      354         master   1.0
# 24    61           0       81         master   1.0
# 25   180          28      410         master   1.0
# 26    49          41      273         master   1.0
# 27    96           6      235         master   1.0
# 28   133          21     1621         master   1.0
# 29    78          41       76         master   1.0
#
# [30 rows x 78 columns]

# %%
github_dat.groupby('visibility').visibility.count()
# Out:
# visibility
# public    30
# Name: visibility, dtype: int64

# %%
#use postman website for api help

# %%
#for homework go find an api and request data
#download some api stuff
