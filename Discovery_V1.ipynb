# %%
#3A2GVOQiKW-43GSQkaznUtehWdi0LKV6H5APWkF4-O_Z

# %%
# !pip install ibm_watson
# Out:
# Collecting ibm_watson
#   Downloading ibm-watson-6.1.0.tar.gz (373 kB)
#      |████████████████████████████████| 373 kB 15.8 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting websocket-client==1.1.0
#   Downloading websocket_client-1.1.0-py2.py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 9.5 MB/s  eta 0:00:01
# Requirement already satisfied: ibm-cloud-sdk-core==3.*,>=3.3.6 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson) (3.10.1)
# Requirement already satisfied: requests<3.0,>=2.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson) (2.26.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson) (2.8.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson) (2.4.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from python-dateutil>=2.5.3->ibm_watson) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests<3.0,>=2.0->ibm_watson) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests<3.0,>=2.0->ibm_watson) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests<3.0,>=2.0->ibm_watson) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests<3.0,>=2.0->ibm_watson) (2.0.4)
# Building wheels for collected packages: ibm-watson
#   Building wheel for ibm-watson (PEP 517) ... done
#   Created wheel for ibm-watson: filename=ibm_watson-6.1.0-py3-none-any.whl size=370748 sha256=3233098a3d621d085506b28cf5f3c23e40cba22e7e325e7e69bbc7213f1b8503
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/bb/d0/34/ff5df539c080e3a57abae75307fdc7ae057478b248a8900c3e
# Successfully built ibm-watson
# Installing collected packages: websocket-client, ibm-watson
# Successfully installed ibm-watson-6.1.0 websocket-client-1.1.0

# %%
import json
from ibm_watson import DiscoveryV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
authenticator = IAMAuthenticator('your_api_key')
authenticator = IAMAuthenticator('3A2GVOQiKW-43GSQkaznUtehWdi0LKV6H5APWkF4-O_Z')

discovery = DiscoveryV1(
    version='2018-08-01',
    authenticator=authenticator)
#discovery.set_service_url('https://api.us-south.discovery.watson.cloud.ibm.com')
discovery.set_service_url('https://api.us-south.discovery.watson.cloud.ibm.com/instances/d5e5bcd7-67cd-442c-8236-6b5326a439ea')

# %%
environments = discovery.list_environments().get_result()
print(json.dumps(environments, indent=2))
# Out:
# {
#   "environments": [
#     {
#       "environment_id": "system",
#       "name": "Watson System Environment",
#       "description": "Shared system data sources",
#       "read_only": true
#     },
#     {
#       "environment_id": "0dd29fd4-3a9e-4ab6-905a-d0e6b0d2e987",
#       "name": "byod",
#       "description": "",
#       "created": "2022-10-22T13:36:37.768Z",
#       "updated": "2022-10-22T13:36:37.768Z",
#       "read_only": false
#     }
#   ]
# }

# %%
news_environment_id = 'system'
print(json.dumps(news_environment_id, indent=2))
# Out:
# "system"

# %%
collections = discovery.list_collections(news_environment_id).get_result()
news_collections = [x for x in collections['collections']]
print(json.dumps(collections, indent=2))
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# /tmp/wsuser/ipykernel_164/2859032578.py in <module>
# ----> 1 collections = discovery.list_collections(news_environment_id).get_result()
#       2 news_collections = [x for x in collections['collections']]
#       3 print(json.dumps(collections, indent=2))
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/ibm_watson/discovery_v1.py in list_collections(self, environment_id, name, **kwargs)
#     800                                        params=params)
#     801
# --> 802         response = self.send(request, **kwargs)
#     803         return response
#     804
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/ibm_cloud_sdk_core/base_service.py in send(self, request, **kwargs)
#     306                                         status_code=response.status_code)
#     307
# --> 308             raise ApiException(response.status_code, http_response=response)
#     309         except requests.exceptions.SSLError:
#     310             logging.exception(self.ERROR_MSG_DISABLE_SSL)
#
# ApiException: Error: The Watson Discovery News feature is no longer available., Code: 410 , X-global-transaction-id: 10d36250-e0f6-4c1b-9374-8bd4a5eebc6f

# %%
configurations = discovery.list_configurations(
    environment_id=news_environment_id).get_result()
print(json.dumps(configurations, indent=2))
# Out:
# {
#   "configurations": []
# }

# %%
query_results = discovery.query(
    news_environment_id,
    news_collections[0]['collection_id'],
    filter='extracted_metadata.sha1::f5*',
    return_fields='extracted_metadata.sha1').get_result()
print(json.dumps(query_results, indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/wsuser/ipykernel_164/4072469573.py in <module>
#       1 query_results = discovery.query(
#       2     news_environment_id,
# ----> 3     news_collections[0]['collection_id'],
#       4     filter='extracted_metadata.sha1::f5*',
#       5     return_fields='extracted_metadata.sha1').get_result()
#
# NameError: name 'news_collections' is not defined
